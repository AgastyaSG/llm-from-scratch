# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlob inline

# %%
def f_1(x):
    return 3*x**2 + 2*x + 1
function1(2)
# Out:
# 17

# %%
#derivative from scratch
x_1=2.0
m_1=-3
c_1=2
h=0.001
y_1 = m_1*x_1 + c_1
x_1+=h
y_2 = m_1*x_1 + c_1
print((y_2-y_1)/h)
# Out:
# -3.0000000000001137

# %%
#value class to see what operands and operators gave rise to the current  expressesion

#return type is a value not just a value
class Value:
    def __init__(self,value,label='',_children = (),  _op = '', grad = 0.0):
        self.value = value
        self._prev = set(_children)
        self._op = _op
        self.label = ''
       # self.grad = L
    def __repr__(self):
        return (f"value = {self.value}")
        
    def __add__(self,other):
        out = Value(self.value + other.value,(self, other), '+')
        return out
    def __mul__(self,other):
        out = Value( self.value * other.value,(self,other), '*')
        return out

a = Value(3.0,label='a')
b = Value(7.0,label='b')
c = a+b;c.label='c'
L = a*b + c ; L.label = 'L'
#print(awa.value)
c
# Out:
# value = 10.0

# %%
def trace(root):
    # builds a set of all nodes and edges in a graph
    nodes, edges = set(), set()

    def build(v):
        if v not in nodes:
            nodes.add(v)
            for child in v._prev:
                edges.add((child, v))
                build(child)

    build(root)
    return nodes, edges


def draw_dot(root):
    dot = Digraph(format='svg', graph_attr={'rankdir': 'LR'})  # LR = left to right

    nodes, edges = trace(root)

    for n in nodes:
        uid = str(id(n))
        # for any value in the graph, create a rectangular ('record') node for it
        dot.node(
            name=uid,
            label="{ %s | value %.4f  }" % (getattr(n, 'label', ''), n.value),
            shape='record'
        )
        if n._op:
            # if this value is a result of some operation, create an op node for it
            dot.node(name=uid + n._op, label=n._op)
            # and connect this op node to the value node
            dot.edge(uid + n._op, uid)

    for n1, n2 in edges:
        # connect n1 to the op node of n2
        dot.edge(str(id(n1)), str(id(n2)) + n2._op)

    return dot

# %%
draw_dot(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 draw_dot(c)
#
# Cell In[89], line 19, in draw_dot(root)
#      16 def draw_dot(root):
#      17     dot = Digraph(format='svg', graph_attr={'rankdir': 'LR'})  # LR = left to right
# ---> 19     nodes, edges = trace(root)
#      21     for n in nodes:
#      22         uid = str(id(n))
#
# Cell In[89], line 12, in trace(root)
#       9             edges.add((child, v))
#      10             build(child)
# ---> 12 build(root)
#      13 return nodes, edges
#
# Cell In[89], line 10, in trace.<locals>.build(v)
#       8 for child in v._prev:
#       9     edges.add((child, v))
# ---> 10     build(child)
#
# Cell In[89], line 8, in trace.<locals>.build(v)
#       6 if v not in nodes:
#       7     nodes.add(v)
# ----> 8     for child in v._prev:
#       9         edges.add((child, v))
#      10         build(child)
#
# AttributeError: 'str' object has no attribute '_prev'
